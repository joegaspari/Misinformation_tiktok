# %% [markdown]
# # Posts NoteBook
#
# In the following notebooke we look to utilize functions built in post_anlysis.py to add analysis values as column entries into our final data set.
# We begin by extracting the data set scraped from TikTok

# %%
import pandas as pd
import post_anlysis as pa


data = pd.read_csv('combined.csv').drop("INDEX", 1)
display(data)
# Out:
# <ipython-input-10-bf4e64275762>:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = pd.read_csv('combined.csv').drop("INDEX", 1)
#                ID                   Nickname  \
# 0    6.890000e+18  Alexandra Kopko (She/Her)
# 1    6.970000e+18                   Gea Love
# 2    7.010000e+18                    jada ☠️
# 3    6.980000e+18                        .qu
# 4    6.910000e+18               Chelsea Hart
# ..            ...                        ...
# 628  6.810000e+18              ADHD survivor
# 629  6.810000e+18                 Emre Balım
# 630  6.800000e+18              Vivek Verma 🎭
# 631  6.810000e+18                Anuj Tkd😘🇮🇳
# 632  6.800000e+18                 oye indori
#
#                                                   Desc  commentCount  \
# 0    #vaccine #biden2020 #antivaxxer #yikes #politi...          9231
# ...

# %% [markdown]
# ## Calculating Miss-Information
#
# *Our poly-grams are stored in the csv file bigrams.csv, while all our single words are found in unigrams.csv*
#
# If a post contains single words that match this set then we calculate the number of matching words as a the containment between the two sets. The intersection of post unigrams and fake news unigrams is divided by the set size of post unigrams to produce the containment measure. A value close to 1 indicates the post has all if not most words that match our set
#
# We can extract all bi-grams from the posts and determine if they match any of the poly-grams produced by our fake news articles then we can then find the number of matching bi-grams and divide that by the total number of bi-grams produced by our post!

# %%
unigram = pa.unigram_Score( cleaned )
bigram = pa.bigram_Score( cleaned )
#calling these two methods will produce the bigram and unigram scores

# %%
print(unigram)
print(bigram)


d21 = pd.read_csv("combined.csv")
# Out:
# 0.23076923076923078
# 0.0

# %%
#In combined_score we see the unigram and bigram score being generated for each row in the dataframe, using the description we are able to generate ngrams and
#complete a containment calculation. All required methods are found in post_anlysis

nm = pa.combine_score(d21)
# Out:
# /Users/joegaspari/Documents/Documents/Year2/S1/COSC 419F/419F-Group-Project/COVID19-FNIR/post_anlysis.py:160: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop('Desc', 1)

# %%
display(nm)
# Out:
#      INDEX            ID                   Nickname  commentCount  playCount  \
# 0        0  6.890000e+18  Alexandra Kopko (She/Her)          9231    5800000
# 1        1  6.970000e+18                   Gea Love         21500    5100000
# 2        2  7.010000e+18                    jada ☠️         13000    3000000
# 3        3  6.980000e+18                        .qu         17300    2800000
# 4        4  6.910000e+18               Chelsea Hart         12200    2700000
# ..     ...           ...                        ...           ...        ...
# 628    795  6.810000e+18              ADHD survivor         11700   14000000
# 629    796  6.810000e+18                 Emre Balım          3496   17000000
# 630    797  6.800000e+18              Vivek Verma 🎭          3188   58500000
# 631    798  6.810000e+18                Anuj Tkd😘🇮🇳          1449   19700000
# 632    799  6.800000e+18                 oye indori          4759   13300000
#
# ...

# %%
nm.to_csv("Data/combinedScore.csv")
